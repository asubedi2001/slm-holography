# %%
# Perform Fourier Transform on sample image

import os
import numpy as np
from PIL import Image

images = []
for filepath in os.listdir("./images/"):
    images.append('./images/' + filepath)

im_raw = Image.open(images[0])
im_ndarr = np.array(im)

# %%
from scipy.fft import fft2
from scipy.fft import fftshift

im_grey = np.array(im_raw.convert("L"))

im_rand = np.random.randint(0, 256, (400, 400), dtype=np.uint8)

im_fft2d = fft2(im_rand)
im_fshift = fftshift(im_rand)

magnitude_spectrum = 20 * np.log(np.abs(im_fshift))
# Out:
# C:\Users\Aakas\AppData\Local\Temp\ipykernel_31168\253608169.py:11: RuntimeWarning: divide by zero encountered in log
#   magnitude_spectrum = 20 * np.log(np.abs(im_fshift))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.subplot(121), plt.imshow(im_rand, cmap='gray'), plt.title('Original Image')
plt.subplot(122), plt.imshow(magnitude_spectrum, cmap='gray'), plt.title('Magnitude Spectrum')
plt.show()

# %%
im2 = np.zeros((400, 400))

im2[20:40, 20:40] = 1
im2[360:380, 360:380] = 1

imgplot = plt.imshow(im2)
plt.show()

# %%
from scipy.fft import ifft2

im2_fft2d = ifft2(im_rand)
im2_fshift = fftshift(im_rand)

im2_magnitude_spectrum = 20 * np.log(np.abs(im2_fshift))
# Out:
# C:\Users\Aakas\AppData\Local\Temp\ipykernel_31168\2018412087.py:6: RuntimeWarning: divide by zero encountered in log
#   im2_magnitude_spectrum = 20 * np.log(np.abs(im2_fshift))

# %%
plt.figure(figsize=(10, 6))
plt.subplot(121), plt.imshow(im2, cmap='gray'), plt.title('Original Image')
plt.subplot(122), plt.imshow(im2_magnitude_spectrum, cmap='gray'), plt.title('Magnitude Spectrum')
plt.show()
